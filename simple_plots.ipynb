# %%
#%matplotlib qt

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as anim

fig, ax = plt.subplots()
line, = ax.plot(np.random.rand(10))
ax.set_ylim(0,1)

def update(data):
    line.set_ydata(data)
    return line,

def data_gen():
    while True:
        yield np.random.rand(10)
        
ani = anim.FuncAnimation(fig,update,data_gen,interval=100)
plt.show()

# %%
# %matplotlib --list
# Out:
# Available matplotlib backends: ['qt5', 'nbagg', 'osx', 'tk', 'qt', 'gtk', 'qt4', 'inline', 'notebook', 'gtk3', 'wx']

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(0,3*np.pi,500)
plt.title("A simple plot")
plt.plot(x,np.sin(x**2))

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0,3*np.pi,500)
plt.title("Another plot")
plt.plot(np.cos(x),np.sin(x))

# %%
plt.plot(np.cos(x)*np.sin(x),(np.sin(x)))

# %%
plt.plot(np.cos(x)*np.sin(x**2),np.sin(x)*np.cos(x**2))

# %%
plt.plot(np.cos(x)*np.sin(x**2),((np.sin(x))**2)*np.cos(x**2))

# %%
plt.plot(np.sin(3*x),np.cos(2*x))

# %%
t=np.linspace(0,2*np.pi,200)
x=np.sin(t)
y=np.cos(3*t)
plt.plot(x,y)

# %%
plt.plot(np.cos(t+np.pi/4),np.sin(2*t))

# %%
plt.plot(2*np.cos(t),np.cos(t+4))

# %%
plt.plot(np.sin(2*t),np.cos(3*t))

# %%
plt.plot(np.sin(2*t),np.cos(5*t))

# %%
plt.plot(np.sin(3*t),np.cos(5*t))
